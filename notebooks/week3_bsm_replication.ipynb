# %% [markdown]
# # Week 3 - Original BSM Model Replication
#
# This notebook implements the chooser-option setup from the paper using a Black-Scholes decomposition.
#
# $$V_{chooser} = C(S, K, T) + Peft(S, K e^{-r(T-t)}, T-t
# ight)$$

# %%
from pathlib import Path
import json
import sys

ROOT = Path.cwd()
if not (ROOT / 'scripts').exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'scripts'))

from week3_bsm import (
    build_validation_frames,
    chooser_valuation_breakdown,
    load_parameters,
)

parameters = load_parameters(ROOT / 'configs' / 'week3_bsm_parameters.json')
breakdown = chooser_valuation_breakdown(parameters)
summary_frame, sensitivity_frame = build_validation_frames(parameters)
breakdown

# %%
summary_frame

# %%
sensitivity_frame

# %% [markdown]
# The key replication checks are:
#
# - the chooser value is the call leg plus the adjusted put leg, and
# - the identity gap is numerically zero apart from floating-point rounding.
