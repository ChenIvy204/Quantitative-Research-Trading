# %% [markdown]
# # Week 3 - BSM Validation Notebook
#
# This notebook checks the chooser-option implementation against the paper parameters and inspects basic sensitivity around the published base case.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
if not (ROOT / 'scripts').exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'scripts'))

from week3_bsm import build_validation_frames, chooser_valuation_breakdown, load_parameters

parameters = load_parameters(ROOT / 'configs' / 'week3_bsm_parameters.json')
breakdown = chooser_valuation_breakdown(parameters)
summary_frame, sensitivity_frame, greeks_frame = build_validation_frames(parameters)
breakdown

# %%
summary_frame

# %%
sensitivity_frame

# %% [markdown]
# Validation checklist:
#
# 1. The chooser identity gap should be approximately zero.
# 2. The chooser value should increase with the underlying spot price in the sensitivity table.
# 3. The call leg and put leg should be consistent with the parameter set from the paper.
